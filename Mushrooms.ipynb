# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.count()
# Out:
# class                       8124
# cap-shape                   8124
# cap-surface                 8124
# cap-color                   8124
# bruises                     8124
# odor                        8124
# gill-attachment             8124
# gill-spacing                8124
# gill-size                   8124
# gill-color                  8124
# stalk-shape                 8124
# stalk-root                  8124
# stalk-surface-above-ring    8124
# stalk-surface-below-ring    8124
# stalk-color-above-ring      8124
# stalk-color-below-ring      8124
# veil-type                   8124
# veil-color                  8124
# ring-number                 8124
# ring-type                   8124
# spore-print-color           8124
# population                  8124
# habitat                     8124
# dtype: int64

# %%
df.nunique()
# Out:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %%
#Let's confirm if there are no special characters in the dataset. I saw some '?' when copying the CSV data.

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
#P is Poisonous
#E is Edible

# %%
#To find the unique variables in each columns
col = ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
for i in col:
    x = df[i].unique()
    y = df[i].nunique()
    print(i, '\nValues =', x, '|| Count = ', y, '\n')
# Out:
# class
# Values = ['p' 'e'] || Count =  2
#
# cap-shape
# Values = ['x' 'b' 's' 'f' 'k' 'c'] || Count =  6
#
# cap-surface
# Values = ['s' 'y' 'f' 'g'] || Count =  4
#
# cap-color
# Values = ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r'] || Count =  10
#
# bruises
# Values = ['t' 'f'] || Count =  2
#
# odor
# Values = ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm'] || Count =  9
#
# gill-attachment
# Values = ['f' 'a'] || Count =  2
#
# gill-spacing
# Values = ['c' 'w'] || Count =  2
#
# gill-size
# Values = ['n' 'b'] || Count =  2
#
# gill-color
# Values = ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o'] || Count =  12
#
# stalk-shape
# Values = ['e' 't'] || Count =  2
#
# stalk-root
# Values = ['e' 'c' 'b' 'r' '?'] || Count =  5
#
# stalk-surface-above-ring
# Values = ['s' 'f' 'k' 'y'] || Count =  4
#
# stalk-surface-below-ring
# Values = ['s' 'f' 'y' 'k'] || Count =  4
#
# stalk-color-above-ring
# Values = ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y'] || Count =  9
#
# stalk-color-below-ring
# ...

# %%
#We can see that there are '?' or unknown values in the dataset which needs to be replaced. [stalk-root column]

# %%
#Considering '?' as a NaN value, we have have to first find the count of the null value. 
df['stalk-root'] = df['stalk-root'].replace(['?'], np.NaN)
df['stalk-root'].isnull().sum()
# Out:
# 2480

# %%
#Since 30.5% of the values are NaN, we can remove that column to make peace with the accuracy provided by every other columns in the dataset.

# %%
df.drop(['stalk-root'], axis = 1, inplace = True)
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
#Since we cannot move forward without encoding, we should do that now.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
col1 = ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
for i in col1: 
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
#Here we can see that all the values are between 0-11 and there isn't much difference between the mean to the min and max values.

# %%
#To find outliers
df.plot(kind = 'box', subplots = True, figsize = (10, 70), layout = (22,3))
# Out:
# class                          AxesSubplot(0.125,0.851183;0.227941x0.0288168)
# cap-shape                   AxesSubplot(0.398529,0.851183;0.227941x0.0288168)
# cap-surface                 AxesSubplot(0.672059,0.851183;0.227941x0.0288168)
# cap-color                      AxesSubplot(0.125,0.816603;0.227941x0.0288168)
# bruises                     AxesSubplot(0.398529,0.816603;0.227941x0.0288168)
# odor                        AxesSubplot(0.672059,0.816603;0.227941x0.0288168)
# gill-attachment                AxesSubplot(0.125,0.782023;0.227941x0.0288168)
# gill-spacing                AxesSubplot(0.398529,0.782023;0.227941x0.0288168)
# gill-size                   AxesSubplot(0.672059,0.782023;0.227941x0.0288168)
# gill-color                     AxesSubplot(0.125,0.747443;0.227941x0.0288168)
# stalk-shape                 AxesSubplot(0.398529,0.747443;0.227941x0.0288168)
# stalk-surface-above-ring    AxesSubplot(0.672059,0.747443;0.227941x0.0288168)
# ...

# %%
#We can see that there are multiple columns with outliers, but they are minimal. No huge variances.

# %%
sb.pairplot(df)

# %%
#To find the correlation
dfcor = df.corr()
dfcor
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-surface-above-ring -0.334593  -0.030417     0.089090  -0.060837
# ...

# %%
#Plotting correlation using heatmap
fig = plt.figure(figsize = (15,10))
sb.heatmap(dfcor, annot = True)

# %%
#On the heatmap, veil color is shown as an empty column as the whole column has 1 value, and when encoded, it became 0

# %%
#Moving on to Classification
#Splitting x & y variables
from sklearn.model_selection import train_test_split
x = df.iloc[:, 1:22]
x.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# ...

# %%
#Standard Scaling x values
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
x = std.fit_transform(x)

# %%
y = df.iloc[:, 0]
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int32

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .30, random_state = 100)

# %%
x_train.shape
# Out:
# (5686, 21)

# %%
x_test.shape
# Out:
# (2438, 21)

# %%
y_train.shape
# Out:
# (5686,)

# %%
y_test.shape
# Out:
# (2438,)

# %%
#Running all the models
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
lr.score(x_train, y_train)
predlr = lr.predict(x_test)
print('Accuracy Score of ', lr, ' is:')
print(accuracy_score(y_test, predlr))
print(confusion_matrix(y_test, predlr))
print(classification_report(y_test, predlr))
print('\n')
# Out:
# Accuracy Score of  LogisticRegression()  is:
# 0.9499589827727646
# [[1205   53]
#  [  69 1111]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      1258
#            1       0.95      0.94      0.95      1180
#
#     accuracy                           0.95      2438
#    macro avg       0.95      0.95      0.95      2438
# weighted avg       0.95      0.95      0.95      2438

# %%
svc = SVC()
svc.fit(x_train, y_train)
svc.score(x_train, y_train)
predsvc = svc.predict(x_test)
print('Accuracy Score of ', svc, ' is:')
print(accuracy_score(y_test, predsvc))
print(confusion_matrix(y_test, predsvc))
print(classification_report(y_test, predsvc))
# Out:
# Accuracy Score of  SVC()  is:
# 1.0
# [[1258    0]
#  [   0 1180]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1258
#            1       1.00      1.00      1.00      1180
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
gnb.score(x_train, y_train)
predgnb = gnb.predict(x_test)
print('Accuracy Score of ', gnb, ' is:')
print(accuracy_score(y_test, predgnb))
print(confusion_matrix(y_test, predgnb))
print(classification_report(y_test, predgnb))
# Out:
# Accuracy Score of  GaussianNB()  is:
# 0.9245283018867925
# [[1161   97]
#  [  87 1093]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93      1258
#            1       0.92      0.93      0.92      1180
#
#     accuracy                           0.92      2438
#    macro avg       0.92      0.92      0.92      2438
# weighted avg       0.92      0.92      0.92      2438

# %%
mnb = MultinomialNB()
mnb.fit(x_train, y_train)
mnb.score(x_train, y_train)
predmnb = mnb.predict(x_test)
print('Accuracy Score of ', mnb, ' is:')
print(accuracy_score(y_test, predmnb))
print(confusion_matrix(y_test, predmnb))
print(classification_report(y_test, predmnb))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-10f8199795a8> in <module>
#       1 mnb = MultinomialNB()
# ----> 2 mnb.fit(x_train, y_train)
#       3 mnb.score(x_train, y_train)
#       4 predmnb = mnb.predict(x_test)
#       5 print('Accuracy Score of ', mnb, ' is:')
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     639
#     640         self._init_counters(n_effective_classes, n_features)
# --> 641         self._count(X, Y)
#     642         alpha = self._check_alpha()
#     643         self._update_feature_log_prob(alpha)
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in _count(self, X, Y)
#     761     def _count(self, X, Y):
#     762         """Count and smooth feature occurrences."""
# --> 763         check_non_negative(X, "MultinomialNB (input X)")
# ...

# %%
#MultinomialNB doesn't work here because of the negative values.

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
rfc.score(x_train, y_train)
predrfc = rfc.predict(x_test)
print('Accuracy Score of ', rfc, ' is:')
print(accuracy_score(y_test, predrfc))
print(confusion_matrix(y_test, predrfc))
print(classification_report(y_test, predrfc))
# Out:
# Accuracy Score of  RandomForestClassifier()  is:
# 1.0
# [[1258    0]
#  [   0 1180]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1258
#            1       1.00      1.00      1.00      1180
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
knn.score(x_train, y_train)
predknn = knn.predict(x_test)
print('Accuracy Score of ', knn, ' is:')
print(accuracy_score(y_test, predknn))
print(confusion_matrix(y_test, predknn))
print(classification_report(y_test, predknn))
# Out:
# Accuracy Score of  KNeighborsClassifier()  is:
# 1.0
# [[1258    0]
#  [   0 1180]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1258
#            1       1.00      1.00      1.00      1180
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
dtc.score(x_train, y_train)
preddtc = dtc.predict(x_test)
print('Accuracy Score of ', dtc, ' is:')
print(accuracy_score(y_test, preddtc))
print(confusion_matrix(y_test, preddtc))
print(classification_report(y_test, preddtc))
# Out:
# Accuracy Score of  DecisionTreeClassifier()  is:
# 1.0
# [[1258    0]
#  [   0 1180]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1258
#            1       1.00      1.00      1.00      1180
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
#Doing Cross Validation
from sklearn.model_selection import cross_val_score

# %%
cvm = [lr, svc, gnb, mnb, rfc, knn, dtc]
for i in cvm:
    scores = cross_val_score(i, x, y, cv = 5)
    print('Cross validation Scores for ', i)
    print(scores)
    print('Mean Score: ', scores.mean(), 'Standard deviation:', scores.std())
    print('\n')
    print('\n')
# Out:
# Cross validation Scores for  LogisticRegression()
# [0.67015385 0.97784615 0.87323077 0.99692308 0.68041872]
# Mean Score:  0.8397145130731337 Standard deviation: 0.1407438750818319
#
#
#
#
# Cross validation Scores for  SVC()
# [0.84246154 1.         0.96       1.         0.56465517]
# Mean Score:  0.8734233421750662 Standard deviation: 0.1648242908307618
#
#
#
#
# Cross validation Scores for  GaussianNB()
# [0.66830769 0.93415385 0.80061538 0.69476923 0.50923645]
# Mean Score:  0.7214165214096248 Standard deviation: 0.14147836332391586
#
#
#
#
# Cross validation Scores for  MultinomialNB()
# [nan nan nan nan nan]
# Mean Score:  nan Standard deviation: nan
#
#
#
#
# Cross validation Scores for  RandomForestClassifier()
# [0.84246154 1.         0.99876923 1.         0.6570197 ]
# Mean Score:  0.8996500947328533 Standard deviation: 0.13572387215819004
#
#
#
#
# Cross validation Scores for  KNeighborsClassifier()
# [0.84246154 1.         0.95015385 1.         0.61514778]
# ...

# %%
#When compared with the difference between the accuracy score of original model vs the cross val score, DecisionTreeClassifier turned out to have the least difference

# %%
#When running the models, I had added AdaBoostClassifier, and it turned out to be the best method, but I removed it since it's an Ensemble Technique. As per my knowledge, emsemble techniques are only used for large datasets.

# %%
#Making the model file. 
import joblib
joblib.dump(dtc, 'Mushrooms.obj')
# Out:
# ['Mushrooms.obj']

# %%
#Importing the model once again to make predictions
dtc_joblib = joblib.load('Mushrooms.obj')
dtc_joblib.predict(x_test)
# Out:
# array([0, 1, 0, ..., 1, 1, 0])
